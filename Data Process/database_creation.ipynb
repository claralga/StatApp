# %%
import pandas as pd
df1 = pd.read_csv('database_votants.csv')
df2 = pd.read_csv('database_scrutins.csv')

# %% [markdown]
# df_votes = df1.merge(df2, on="idScrutin", how='right')
# df_votes

# %%
df_votes = df_votes[['idScrutin', 'idVotant', 'vote', 'organeRefGroupe', 'date_scrutin', 'code_type_vote',
                    'titre', 'demandeur', 'organe_ref', 'votants', 'pour', 'contre', 'non_votants', 
                     'non_votants_volontaires', 'abstention', 'resultat']]
df_votes
# Out:
#         idScrutin  idVotant        vote organeRefGroupe date_scrutin  \
# 0               0  PA606171  Non-votant        PO730964   2020-10-07
# 1               0  PA721824  Non-votant        PO730964   2020-10-07
# 2               0  PA719952        Pour        PO730964   2020-10-07
# 3               0  PA607395        Pour        PO730964   2020-10-07
# 4               0  PA718710        Pour        PO730964   2020-10-07
# ...           ...       ...         ...             ...          ...
# 308926       3116  PA719608        Pour        PO723569   2020-10-30
# 308927       3116  PA721932        Pour        PO723569   2020-10-30
# 308928       3116    PA1838      Contre        PO723569   2020-10-30
# 308929       3117       NaN         NaN             NaN   2020-07-31
# 308930       3118       NaN         NaN             NaN   2018-12-04
#
#        code_type_vote                                              titre  \
# 0                 SPO  l'article 24 bis du projet de loi portant dive...
# 1                 SPO  l'article 24 bis du projet de loi portant dive...
# 2                 SPO  l'article 24 bis du projet de loi portant dive...
# 3                 SPO  l'article 24 bis du projet de loi portant dive...
# 4                 SPO  l'article 24 bis du projet de loi portant dive...
# ...               ...                                                ...
# 308926            SPO  l'amendement n° 1237 de la commission des fina...
# 308927            SPO  l'amendement n° 1237 de la commission des fina...
# 308928            SPO  l'amendement n° 1237 de la commission des fina...
# 308929            SPO  l'amendement n° 1074 de M. Bazin et les amende...
# 308930            SPO  l'amendement de suppression n°54 de Mme Geneva...
#
#                                                 demandeur organe_ref  votants  \
# 0           Président du groupe "La République en Marche"   PO717460       57
# 1           Président du groupe "La République en Marche"   PO717460       57
# 2           Président du groupe "La République en Marche"   PO717460       57
# 3           Président du groupe "La République en Marche"   PO717460       57
# 4           Président du groupe "La République en Marche"   PO717460       57
# ...                                                   ...        ...      ...
# 308926   Présidente du groupe "Socialistes et apparentés"   PO717460       73
# 308927   Présidente du groupe "Socialistes et apparentés"   PO717460       73
# 308928   Présidente du groupe "Socialistes et apparentés"   PO717460       73
# 308929             Président du groupe "Les Républicains"   PO717460       74
# 308930  Président du groupe "Les Républicains"Présiden...   PO717460      158
#
#         pour  contre  non_votants  non_votants_volontaires  abstention  \
# 0         56       0            2                        0           1
# 1         56       0            2                        0           1
# 2         56       0            2                        0           1
# 3         56       0            2                        0           1
# 4         56       0            2                        0           1
# ...      ...     ...          ...                      ...         ...
# 308926    26      41            2                        0           6
# 308927    26      41            2                        0           6
# 308928    26      41            2                        0           6
# 308929    17      55            2                        0           2
# 308930    64      93            2                        0           1
#
#        resultat
# 0        adopté
# 1        adopté
# 2        adopté
# 3        adopté
# 4        adopté
# ...         ...
# 308926   rejeté
# 308927   rejeté
# 308928   rejeté
# 308929   rejeté
# 308930   rejeté
#
# [308931 rows x 16 columns]

# %%
df_votes.to_csv('database_votes.csv')
