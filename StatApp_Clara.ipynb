# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv(r'database_votes.csv')

# %%
df=df.dropna()
df
# Out:
#         Unnamed: 0  idScrutin  idVotant        vote organeRefGroupe  \
# 0                0          0  PA606171  Non-votant        PO730964
# 1                1          0  PA721824  Non-votant        PO730964
# 2                2          0  PA719952        Pour        PO730964
# 3                3          0  PA607395        Pour        PO730964
# 4                4          0  PA718710        Pour        PO730964
# ...            ...        ...       ...         ...             ...
# 308924      308924       3116  PA335612        Pour        PO730940
# 308925      308925       3116  PA607619      Contre        PO759900
# 308926      308926       3116  PA719608        Pour        PO723569
# 308927      308927       3116  PA721932        Pour        PO723569
# 308928      308928       3116    PA1838      Contre        PO723569
#
#        date_scrutin code_type_vote  \
# 0        2020-10-07            SPO
# 1        2020-10-07            SPO
# 2        2020-10-07            SPO
# 3        2020-10-07            SPO
# 4        2020-10-07            SPO
# ...             ...            ...
# 308924   2020-10-30            SPO
# 308925   2020-10-30            SPO
# 308926   2020-10-30            SPO
# 308927   2020-10-30            SPO
# 308928   2020-10-30            SPO
#
#                                                     titre  \
# 0       l'article 24 bis du projet de loi portant dive...
# 1       l'article 24 bis du projet de loi portant dive...
# 2       l'article 24 bis du projet de loi portant dive...
# 3       l'article 24 bis du projet de loi portant dive...
# 4       l'article 24 bis du projet de loi portant dive...
# ...                                                   ...
# 308924  l'amendement n° 1237 de la commission des fina...
# 308925  l'amendement n° 1237 de la commission des fina...
# 308926  l'amendement n° 1237 de la commission des fina...
# 308927  l'amendement n° 1237 de la commission des fina...
# 308928  l'amendement n° 1237 de la commission des fina...
#
#                                                demandeur organe_ref  votants  \
# 0          Président du groupe "La République en Marche"   PO717460       57
# 1          Président du groupe "La République en Marche"   PO717460       57
# 2          Président du groupe "La République en Marche"   PO717460       57
# 3          Président du groupe "La République en Marche"   PO717460       57
# 4          Président du groupe "La République en Marche"   PO717460       57
# ...                                                  ...        ...      ...
# 308924  Présidente du groupe "Socialistes et apparentés"   PO717460       73
# 308925  Présidente du groupe "Socialistes et apparentés"   PO717460       73
# 308926  Présidente du groupe "Socialistes et apparentés"   PO717460       73
# 308927  Présidente du groupe "Socialistes et apparentés"   PO717460       73
# 308928  Présidente du groupe "Socialistes et apparentés"   PO717460       73
#
#         pour  contre  non_votants  non_votants_volontaires  abstention  \
# 0         56       0            2                        0           1
# 1         56       0            2                        0           1
# 2         56       0            2                        0           1
# 3         56       0            2                        0           1
# 4         56       0            2                        0           1
# ...      ...     ...          ...                      ...         ...
# 308924    26      41            2                        0           6
# 308925    26      41            2                        0           6
# 308926    26      41            2                        0           6
# 308927    26      41            2                        0           6
# 308928    26      41            2                        0           6
#
#        resultat
# 0        adopté
# 1        adopté
# 2        adopté
# 3        adopté
# 4        adopté
# ...         ...
# 308924   rejeté
# 308925   rejeté
# 308926   rejeté
# 308927   rejeté
# 308928   rejeté
#
# [308349 rows x 17 columns]

# %%
Scrutins = df['titre'].unique()
print("Il y a ", len(Scrutins) , "scrutins différents")
# Out:
# Il y a  3109 scrutins différents

# %%
Votants = df['idVotant'].unique()
Votants.astype(str)
print("Il y a ", len(Votants) , "votants différents")
# Out:
# Il y a  638 votants différents

# %%
Nombre_votants_par_scrutin = df.groupby("titre")['votants'].count().reset_index().sort_values(by='votants',ascending = False)
Nombre_votants_par_scrutin
# Out:
#                                                   titre  votants
# 1899  l'amendement n° 793 de M. Ruffin à l'article 3...      575
# 1413  l'amendement n° 36 de M. Bernalicis après l'ar...      574
# 2556  l'ensemble de la proposition de loi relative à...      574
# 2637  l'ensemble du projet de loi de finances rectif...      573
# 2568  l'ensemble de la proposition de loi visant à a...      572
# ...                                                 ...      ...
# 997   l'amendement n° 226 de M. Huyghe après l'artic...       23
# 2516  l'article unique du projet de loi autorisant l...       22
# 1090  l'amendement n° 242 de Mme Autain et les amend...       20
# 2849  la motion de renvoi en commission, déposée par...       18
# 2487  l'article unique de la proposition de loi pour...       16
#
# [3109 rows x 2 columns]

# %%
Avis_votant = pd.DataFrame(df.groupby(['idVotant']).vote.value_counts())
Avis_votant=Avis_votant.rename(columns={'vote':'nombre'})
Total_votant = df.groupby(['idVotant']).vote.count()

# %%
#Création d'un tableau répetoriant pour chaque votant sa proportion de Pour/Contre

Avis_votant = pd.DataFrame(df.groupby(['idVotant']).vote.value_counts())
Avis_votant=Avis_votant.rename(columns={'vote':'nombre'})
Total_votant = df.groupby(['idVotant']).vote.count()
Proportion_vote = pd.DataFrame({'Proportion' : Avis_votant['nombre'].div(Total_votant)*100})
Proportion_vote
# Out:
#                  Proportion
# idVotant vote
# PA1008   Pour     68.944099
#          Contre   31.055901
# PA1012   Pour     65.765766
#          Contre   34.234234
# PA1029   Contre   51.818182
# ...                     ...
# PA923    Contre   41.991342
# PA942    Contre   50.111359
#          Pour     49.888641
# PA998    Contre   55.000000
#          Pour     45.000000
#
# [1290 rows x 1 columns]

# %%
times = pd.DatetimeIndex(df.date_scrutin)
df2 = df.set_index(keys = times)

# %%
#df3 = pd.DataFrame(df2.groupby(by=[pd.Grouper(freq='1A', base = 0, label = 'left'),'idVotant','vote','titre']))

# %%
Demandeurs = df.groupby("demandeur")['resultat'].count().reset_index().sort_values(by='resultat',ascending = False)
Demandeurs
# Out:
#                                              demandeur  resultat
# 73              Président du groupe "Les Républicains"     60422
# 27           Président du groupe "La France insoumise"     50986
# 119  Président du groupe "de la Gauche démocrate et...     35943
# 155   Présidente du groupe "Socialistes et apparentés"     27773
# 4                            Conférence des Présidents     24929
# ..                                                 ...       ...
# 144         Président( du groupe "La France insoumise"        36
# 120  Président du groupe "de la Gauche démocrate et...        35
# 111  Président du groupe "UDI, Agir et Indépendants...        34
# 54   Président du groupe "La République en Marche"\...        33
# 40   Président du groupe "La France insoumise"Prési...        29
#
# [176 rows x 2 columns]

# %%
#Proportion et nombre de propositions adoptées/rejetées par demandeur 
Resultats_demandeur = pd.DataFrame(df.groupby(['demandeur']).resultat.value_counts())
Resultats_demandeur=Resultats_demandeur.rename(columns={'resultat':'nombre'})

demandeurs = df.groupby(['demandeur']).resultat.count()
Proportion_dem = pd.DataFrame({'Proportion' : Resultats_demandeur['nombre'].div(demandeurs)*100})

Proportion_resultats_dem=pd.concat([Resultats_demandeur,Proportion_dem['Proportion']],axis=1)
Proportion_resultats_dem
# Out:
#                                                              nombre  \
# demandeur                                          resultat
# "\rPresident(e) du groupe "de la Gauche démocra... rejeté       132
# Commission                                         adopté        78
# Commission spéciale                                adopté        94
# Conference des Presidents                          adopté       446
# Conférence des Présidents                          adopté     23372
# ...                                                             ...
# Présidente du groupe "Socialistes et apparentés... rejeté       131
# Présidente du groupe "Socialistes et apparentés... adopté       123
# Présidente du groupe "Socialistes et apparentés... rejeté       436
#                                                    adopté       352
# Présidente du groupe "Socialistes et apparentés... adopté        66
#
#                                                              Proportion
# demandeur                                          resultat
# "\rPresident(e) du groupe "de la Gauche démocra... rejeté    100.000000
# Commission                                         adopté    100.000000
# Commission spéciale                                adopté    100.000000
# Conference des Presidents                          adopté    100.000000
# Conférence des Présidents                          adopté     93.754262
# ...                                                                 ...
# Présidente du groupe "Socialistes et apparentés... rejeté    100.000000
# Présidente du groupe "Socialistes et apparentés... adopté    100.000000
# Présidente du groupe "Socialistes et apparentés... rejeté     55.329949
#                                                    adopté     44.670051
# Présidente du groupe "Socialistes et apparentés... adopté    100.000000
#
# [219 rows x 2 columns]

# %%
Partis = pd.DataFrame(df.groupby('idVotant')['organeRefGroupe'].unique())

# %%
#Création d'un indice qui donne le pourcentage de comptabilité entre le vote du votant (Pour/Contre) et la décision finale (Accord/Rejet)
df3= df[((df.vote == 'Pour') & (df.resultat == 'adopté')) | ((df.vote == 'Contre') & (df.resultat == 'rejeté'))]

Accord_votant = df3.idVotant.value_counts() 
Total_votant = df.idVotant.value_counts()

IndiceAccord=[]

Partis2 = []
Nom_Partis = []
Votants2=df3['idVotant'].unique()
for votant in Votants2:     
    IndiceAccord.append(int(Accord_votant[votant])/int(Total_votant[votant])*100)
    Partis2.append(Partis.organeRefGroupe[votant][0])
    Nom_Partis.append(Partis.organeRefGroupe[votant][0])

# %%
IndiceAccordDF = pd.DataFrame({'idVotant' : Votants2,
                               'IndiceAccord' : IndiceAccord,
                               'Parti' : Partis2,
                               'Nom_Parti' : Nom_Partis})

# %%
#Certains groupes politiques reviennent plusieurs fois sous des ID différents, on va donc les regrouper

New=IndiceAccordDF.Nom_Parti.copy()
New=New.replace(['PO774834','PO730970'],'MoDem')
New=New.replace(['PO730964'],'LREM')
New=New.replace(['PO771789'],'Ecologie Démocratie Solidarité')
New=New.replace(['PO771923'],'Agir Ensemble')
New=New.replace(['PO767217','PO744425'],'UDI_Agir')
New=New.replace(['PO765636','PO771889'],'UDI_Independants')
New=New.replace(['PO730952'],'Les Constructifs')
New=New.replace(['PO759900'],'Libertés et Territoires')
New=New.replace(['PO730934'],'LR')
New=New.replace(['PO723569'],'Non inscrits')
New=New.replace(['PO730946'],'Nouvelle Gauche')
New=New.replace(['PO758835'],'Socialistes')
New=New.replace(['PO730940'],'Gauche Dem et Rep')
New=New.replace(['PO730958'],'France Insoumise')

# %%
IndiceAccordDF['Nom_Parti']=New

# %%
ResultatsPartis = IndiceAccordDF.groupby('Nom_Parti')['IndiceAccord'].describe()
ResultatsPartis.sort_values(by="mean",ascending = False)
# Out:
#                                 count       mean        std        min  \
# Nom_Parti
# LREM                            322.0  72.919510   6.233247  19.478403
# MoDem                            52.0  69.768698   7.897399  46.900270
# Ecologie Démocratie Solidarité    4.0  64.833684   3.460599  60.080645
# Agir Ensemble                     6.0  64.010349   6.458783  55.670103
# Les Constructifs                  3.0  49.304243   7.958870  40.145985
# UDI_Agir                         20.0  48.782029  10.364085  25.000000
# UDI_Independants                  7.0  47.359058  11.962732  27.272727
# Libertés et Territoires          18.0  45.184510  13.353068  29.652352
# LR                              117.0  39.073104   5.828192  14.285714
# Non inscrits                     15.0  38.101030   8.467128  28.409091
# Nouvelle Gauche                  12.0  33.133730   4.193260  28.526646
# Socialistes                      24.0  31.517452   6.426156  14.893617
# Gauche Dem et Rep                18.0  30.652187   5.731629  24.297753
# France Insoumise                 17.0  30.179673   1.909435  27.155963
#
#                                       25%        50%        75%         max
# Nom_Parti
# LREM                            71.892269  74.255322  75.659075   88.000000
# MoDem                           66.732106  70.145256  72.606597  100.000000
# Ecologie Démocratie Solidarité  64.015136  65.436426  66.254974   68.381241
# Agir Ensemble                   60.565580  64.161634  65.529045   74.716981
# Les Constructifs                46.683637  53.221289  53.883372   54.545455
# UDI_Agir                        45.998145  47.796702  53.807631   67.410714
# UDI_Independants                44.762373  48.421053  49.045785   68.203310
# Libertés et Territoires         35.391757  41.765463  52.723973   72.018349
# LR                              36.994220  39.002933  41.509434   58.333333
# Non inscrits                    32.392830  37.378641  40.788019   63.184080
# Nouvelle Gauche                 30.192873  31.842075  35.303546   42.307692
# Socialistes                     27.808869  31.634572  33.964206   46.666667
# Gauche Dem et Rep               26.846092  28.646494  33.874907   42.857143
# France Insoumise                28.521739  30.500000  31.491713   33.061889

# %%
plot=sns.relplot(data=IndiceAccordDF,kind="scatter", x="Nom_Parti",y="IndiceAccord", hue="Nom_Parti")
plot.set_xticklabels(rotation=90)

# %% [raw]
# Un IndiceAccord élevé indique que lorsque le député vote, il est généralement d'accord avec la décision finale.
# (ie. Si l'on calculait l'IndiceAccord de la colonne resultat, il serait égal à 100%)
# Cet indice ne prend pas en compte l'abstention du député.
#
# Chaque point représentant un député, on peut deviner la position et la dispersion de chaque groupe politique vis-à-vis des décisions de l'Assemblée Nationale.
